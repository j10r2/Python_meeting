# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Titanic.csv")

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked age_gr            fare_gr
# 0      0         A/5 21171   7.2500   NaN        S  young  (-0.512, 102.466]
# 1      0          PC 17599  71.2833   C85        C    mid  (-0.512, 102.466]
# 2      0  STON/O2. 3101282   7.9250   NaN        S  young  (-0.512, 102.466]
# 3      0            113803  53.1000  C123        S  young  (-0.512, 102.466]
# 4      0            373450   8.0500   NaN        S  young  (-0.512, 102.466]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  age_gr       714 non-null    category
#  13  fare_gr      891 non-null    category
# dtypes: category(2), float64(2), int64(5), object(5)
# memory usage: 85.8+ KB

# %% [markdown]
# # Описательная таблица

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Из данной таблицы мы видим, что в наборе данных содержится 891 строка, что соответствует 891 пассажиру. Средний **коэффициент выживаемости** составляет 38,38%. Пассажиров 3 класса было больше 50%. 25% пассажиров имели возраст до ~20 лет, ещё 25% - от 20 до 28 лет, ещё 25% - от 28 до 38 лет, и оставшиеся 25% были старше 38 лет.

# %% [markdown]
# Для дальнейшего анализа добавим деление пассажиров на возрастные группы (0-15 лет, 15-35 лет, 35-55 лет, старше 55 лет)

# %%
age_groups = [[0, 15, 35, 55, 100],['kids', 'young', 'mid', 'old']]

# %%
df['age_gr']= pd.cut(df['Age'],
                     bins=age_groups[0],
                     labels=age_groups[1])

# %%
df['fare_gr']= pd.cut(df['Fare'],
                     bins=5)

# %% [markdown]
# Рассмотрим **коэффициент выживаемости** в зависимости от **порта посадки**:

# %%
df.groupby('Embarked', as_index = False).agg({'PassengerId':'count', 'Survived':['sum','mean']})
# Out:
#   Embarked PassengerId Survived
#                  count      sum      mean
# 0        C         168       93  0.553571
# 1        Q          77       30  0.389610
# 2        S         644      217  0.336957

# %% [markdown]
# Из таблицы видно, что наиболее высокий коэффициент выживания у пассажиров, севших в порте Шербур, для пассажиров из Квинстауна коэффициент соответствует среднему (0,38), а для пассажиров из Саутгемптона он ниже среднего. Рассмотрим версию, что коэффициент выживаемости зависит от класса:

# %%
df.groupby(['Embarked', 'Pclass']).agg({'Pclass':'count', 'Survived':'mean'}).round(2)
# Out:
#                  Pclass  Survived
# Embarked Pclass
# C        1           85      0.69
#          2           17      0.53
#          3           66      0.38
# Q        1            2      0.50
#          2            3      0.67
#          3           72      0.38
# S        1          127      0.58
#          2          164      0.46
#          3          353      0.19

# %%
plt.pie(vis_taxi.col, labels=vis_taxi.source, autopct='%.0f%%', colors = sns.color_palette('pastel')[7:12])

# %% [markdown]
# Согласно данной таблице, в порту Шербур доля пассажиров первого класса выше, чем в остальных. Вероятно, именно это влияет на коэффициент выживаемости по порту посадки. Однако, также можно заметить, что для всех классов пассажиров, севших в Шербуре, коэффициент выживаемости выше, чем для тех, кто сел в Саутгемптоне.

# %%
df.query('Sex == "female"').\
            groupby(['Embarked', 'age_gr']).\
            agg({'age_gr':'count', 'Pclass':'mean', 'Survived':['sum','mean']}).round(2)
# Out:
#                 age_gr Pclass Survived
#                  count   mean      sum  mean
# Embarked age_gr
# C        kids       13   2.85       11  0.85
#          young      27   1.48       25  0.93
#          mid        18   1.11       16  0.89
#          old         3   1.00        3  1.00
# Q        kids        1   3.00        1  1.00
#          young      10   2.70        6  0.60
#          mid         1   3.00        0  0.00
#          old         0    NaN        0   NaN
# S        kids       29   2.52       16  0.55
#          young     108   2.19       81  0.75
#          mid        44   1.98       32  0.73
#          old         5   1.60        4  0.80

# %%
df.query('Sex == "male"').\
            groupby(['Embarked', 'age_gr']).\
            agg({'age_gr':'count', 'Pclass':'mean', 'Survived':['sum','mean']}).round(2)
# Out:
#                 age_gr Pclass Survived
#                  count   mean      sum  mean
# Embarked age_gr
# C        kids        5   2.80        3  0.60
#          young      41   2.07       14  0.34
#          mid        15   1.33        5  0.33
#          old         8   1.00        2  0.25
# Q        kids        4   3.00        0  0.00
#          young       6   3.00        1  0.17
#          mid         3   2.33        0  0.00
#          old         3   2.67        0  0.00
# S        kids       31   2.55       18  0.58
#          young     222   2.61       31  0.14
#          mid        95   2.04       17  0.18
#          old        20   1.65        2  0.10

# %%
new_df = df.groupby(['Embarked', 'age_gr'], as_index = True).\
            agg({'age_gr':'count'})

# %%
new_df['f_total_col'] = df.query('Sex == "female"').groupby(['Embarked', 'age_gr']).agg({'Survived':'count'}).round(2)
new_df['m_total_col'] = df.query('Sex == "male"').groupby(['Embarked', 'age_gr']).agg({'Survived':'count'}).round(2)
new_df['f_surv_col'] = df.query('Sex == "female"').groupby(['Embarked', 'age_gr']).agg({'Survived':'sum'}).round(2)
new_df['m_surv_col'] = df.query('Sex == "male"').groupby(['Embarked', 'age_gr']).agg({'Survived':'sum'}).round(2)
new_df['f_surv_q'] = df.query('Sex == "female"').groupby(['Embarked', 'age_gr']).agg({'Survived':'mean'}).round(2)
new_df['m_surv_q'] = df.query('Sex == "male"').groupby(['Embarked', 'age_gr']).agg({'Survived':'mean'}).round(2)

# %%
new_df.drop('age_gr', axis=1)
# Out:
#                  f_total_col  m_total_col  f_surv_col  m_surv_col  f_surv_q  \
# Embarked age_gr
# C        kids             13            5          11           3      0.85
#          young            27           41          25          14      0.93
#          mid              18           15          16           5      0.89
#          old               3            8           3           2      1.00
# Q        kids              1            4           1           0      1.00
#          young            10            6           6           1      0.60
#          mid               1            3           0           0      0.00
#          old               0            3           0           0       NaN
# S        kids             29           31          16          18      0.55
#          young           108          222          81          31      0.75
#          mid              44           95          32          17      0.73
#          old               5           20           4           2      0.80
#
#                  m_surv_q
# Embarked age_gr
# C        kids        0.60
#          young       0.34
#          mid         0.33
#          old         0.25
# Q        kids        0.00
#          young       0.17
#          mid         0.00
#          old         0.00
# S        kids        0.58
#          young       0.14
#          mid         0.18
#          old         0.10

# %%
df.groupby(["Sex", "Pclass", "age_gr"]). \
    agg({'PassengerId':'count', 'Age':'mean', 'Survived': 'mean'}). \
    round(2)
# Out:
#                       PassengerId    Age  Survived
# Sex    Pclass age_gr
# female 1      kids              3  10.33      0.67
#               young            44  25.50      0.98
#               mid              31  44.32      0.97
#               old               7  59.29      1.00
#        2      kids             10   6.60      1.00
#               young            44  26.60      0.93
#               mid              19  43.79      0.89
#               old               1  57.00      0.00
#        3      kids             30   7.10      0.53
#               young            57  23.83      0.49
#               mid              14  41.71      0.14
#               old               1  63.00      1.00
# male   1      kids              3   5.31      1.00
#               young            32  27.12      0.50
#               mid              47  44.37      0.38
#               old              19  63.16      0.16
#        2      kids              9   2.26      1.00
#               young            60  26.56      0.07
#               mid              24  43.98      0.04
#               old               6  62.33      0.17
#        3      kids             28   6.52      0.32
#               young           177  24.69      0.15
#               mid              42  42.13      0.07
#               old               6  64.17      0.00

# %%
plt.figure(figsize=(15,10))
sns.countplot(df.Survived, hue=df.age_gr)
# Out:
# C:\Users\j10r2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
df.groupby(["Sex", "Pclass", 'age_gr']).agg({'age_gr': 'value_counts'}).round(2)
# Out:
#                             age_gr
# Sex    Pclass age_gr
# female 1      kids   kids        3
#                      young       0
#                      mid         0
#                      old         0
#               young  young      44
# ...                            ...
# male   3      mid    old         0
#               old    old         6
#                      kids        0
#                      young       0
#                      mid         0
#
# [96 rows x 1 columns]

# %%
df.query('Sex == "female"').groupby(['Pclass', 'age_gr']).agg({'PassengerId':'count','Survived':'mean'})
# Out:
#                PassengerId  Survived
# Pclass age_gr
# 1      kids              3  0.666667
#        young            44  0.977273
#        mid              31  0.967742
#        old               7  1.000000
# 2      kids             10  1.000000
#        young            44  0.931818
#        mid              19  0.894737
#        old               1  0.000000
# 3      kids             30  0.533333
#        young            57  0.491228
#        mid              14  0.142857
#        old               1  1.000000

# %%
df.query('Sex == "female" and age_gr == "kids"').groupby('Pclass').agg({'PassengerId':'count', 'Survived':'sum'})
# Out:
#         PassengerId  Survived
# Pclass
# 1                 3         2
# 2                10        10
# 3                30        16
